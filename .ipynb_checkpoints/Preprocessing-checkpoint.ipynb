# %%
import pandas as pd 
import numpy as np
import os,csv
import matplotlib.pyplot as plt
from sklearn import linear_model, preprocessing, cross_validation, svm
import tensorflow as tf
from sklearn.grid_search import GridSearchCV
import csv
import seaborn as sns
from sklearn.svm import SVC
from PIL import Image
# Out:
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
def get_tables(KID):
    df_dict_KID3=[]   
    path='/Users/user/Research/steady/' + KID + '/'
    collection=[]
    FAN_KID3=[]
    CPU_TEMP_KID3=[]
    FAN1=[]
    CPU_TEMP1=[]
    j=0

    for i in range(1,321):
        try:
            num=str(i) 
            pathex=path+'NN'+num+'.csv'
            collection.append(pathex)
        except:
            print(i, "error1")

    for i in collection:
        j=0
        try:
            df = pd.read_csv(i)
            df=df.iloc[0:,1:2]
            df.column=['Values']
            l=len(df)

            for i in range(3,l,4):
                a=df.ix[i]
                b=df.ix[i+1]
                c=np.array((a+b)/2)
                FAN1.append(c)

            if len(FAN1)!=0:
                FAN_KID3.append(FAN1)
            else:
                print(i,"error2")
            FAN1=[]

            for i in range(1,l,4):
                a=df.ix[i]
                b=df.ix[i+1]
                c=np.array((a+b)/2)
                CPU_TEMP1.append(c)

            CPU_TEMP_KID3.append(CPU_TEMP1)
            CPU_TEMP1=[]


        except:
            FAN_KID3.append(0)
            CPU_TEMP_KID3.append(0)
            print(i,"error3")
            
    temp=[]
    k=len(CPU_TEMP_KID3)

    for i in range(k):
        a=CPU_TEMP_KID3[i]
        f1=pd.Series(a)
        temp.append(f1)

    CPU_table_KID3=pd.concat(temp, axis=1)

    temp=[]
    l=len(FAN_KID3)
    for i in range(l):
        a=FAN_KID3[i]
        f1=pd.Series(a)
        temp.append(f1)

    FAN_table_KID3=pd.concat(temp, axis=1)

    return CPU_table_KID3, FAN_table_KID3

def CPUtemp_vs_time(num, CPU_table_KID):
    A=[]
    l=len(CPU_table_KID[0])

    for i in range(1,l+1):
        A.append(i)

    plt.plot(A,CPU_table_KID[num])
    plt.xlabel("time[s]") 
    plt.ylabel("CPU_temperature")
    plt.title('CPU_Temperature vs time')
    plt.legend()
    plt.show()

def FAN_vs_time(num, FAN_table_KID):
    A=[]
    l=len(FAN_table_KID[0])
    for i in range(1,l+1):
        A.append(i)

    plt.plot(A,FAN_table_KID[num])
    plt.xlabel("time[s]") 
    plt.ylabel("fan rotation speed")
    plt.title('FAN vs time')
    plt.legend()
    plt.show()

# %% [markdown]
# # CPU_outlet_temperature

# %%
dfs = pd.read_excel('/Users/user/Research/import_data/tableForNN.xlsx', sheet_name='steady')
new_dfs=dfs.iloc[1:321,2:14]
new_dfs.columns = ['KID1', 'KID3', 'KID5','KID7','KID9','KID11','CRAC_set','CRAC_out','time','temp1','temp2','temp3']

# %%
new_dfs.describe()
# Out:
#         KID1  KID3  KID5  KID7  KID9  KID11  CRAC_set  CRAC_out  time  temp1  \
# count    320   320   320   320   320    320       320       320     1  320.0
# unique    25    25    25    25    25     25         1         1     1   19.0
# top       17    17    19     9     4     13        80        65  100s   35.5
# freq      19    17    20    19    18     19       320       320     1   50.0
#
#         temp2  temp3
# count   320.0  320.0
# unique   24.0   20.0
# top      34.9   34.9
# freq     36.0   37.0

# %% [markdown]
# # CPU_temperature and Fan rotation speed

# %%
_KID1=get_tables("KID1")
CPU_table_KID1=_KID1[0]
FAN_table_KID1=_KID1[1]
CPU_table_KID1.to_csv('/Users/user/Research/output_csvs/CPU_table_KID1.csv')
FAN_table_KID1.to_csv('/Users/user/Research/output_csvs/FAN_table_KID1.csv')
CPU_table_KID1.to_pickle('/Users/user/Research/output_csvs/CPU_table_KID1.pickle')
FAN_table_KID1.to_pickle('/Users/user/Research/output_csvs/FAN_table_KID1.pickle')
new_dfs['CPU_mean_KID1']=np.array(CPU_table_KID1.mean())
new_dfs['FAN_mean_KID1']=np.array(FAN_table_KID1.mean())
# Out:
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:24: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:29: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ...

# %%
_KID3=get_tables("KID3")
CPU_table_KID3=_KID3[0]
FAN_table_KID3=_KID3[1]
new_dfs['CPU_mean_KID3']=np.array(CPU_table_KID3.mean())
new_dfs['FAN_mean_KID3']=np.array(FAN_table_KID3.mean())
CPU_table_KID3.to_csv('/Users/user/Research/output_csvs/CPU_table_KID3.csv')
FAN_table_KID3.to_csv('/Users/user/Research/output_csvs/FAN_table_KID3.csv')
CPU_table_KID3.to_pickle('/Users/user/Research/output_csvs/CPU_table_KID3.pickle')
FAN_table_KID3.to_pickle('/Users/user/Research/output_csvs/FAN_table_KID3.pickle')
# Out:
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:24: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:29: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ...

# %%
_KID5=get_tables("KID5")
CPU_table_KID5=_KID5[0]
FAN_table_KID5=_KID5[1]
new_dfs['CPU_mean_KID5']=np.array(CPU_table_KID5.mean())
new_dfs['FAN_mean_KID5']=np.array(FAN_table_KID5.mean())
CPU_table_KID5.to_csv('/Users/user/Research/output_csvs/CPU_table_KID5.csv')
FAN_table_KID5.to_csv('/Users/user/Research/output_csvs/FAN_table_KID5.csv')
CPU_table_KID5.to_pickle('/Users/user/Research/output_csvs/CPU_table_KID5.pickle')
FAN_table_KID5.to_pickle('/Users/user/Research/output_csvs/FAN_table_KID5.pickle')
# Out:
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:24: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:29: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ...

# %%
_KID7=get_tables("KID7")
CPU_table_KID7=_KID7[0]
FAN_table_KID7=_KID7[1]
new_dfs['CPU_mean_KID7']=np.array(CPU_table_KID7.mean())
new_dfs['FAN_mean_KID7']=np.array(FAN_table_KID7.mean())
CPU_table_KID7.to_csv('/Users/user/Research/output_csvs/CPU_table_KID7.csv')
FAN_table_KID7.to_csv('/Users/user/Research/output_csvs/FAN_table_KID7.csv')
CPU_table_KID7.to_pickle('/Users/user/Research/output_csvs/CPU_table_KID7.pickle')
FAN_table_KID7.to_pickle('/Users/user/Research/output_csvs/FAN_table_KID7.pickle')
# Out:
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:24: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:29: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ...

# %%
_KID9=get_tables("KID9")
CPU_table_KID9=_KID9[0]
FAN_table_KID9=_KID9[1]
new_dfs['CPU_mean_KID9']=np.array(CPU_table_KID9.mean())
new_dfs['FAN_mean_KID9']=np.array(FAN_table_KID9.mean())
CPU_table_KID9.to_csv('/Users/user/Research/output_csvs/CPU_table_KID9.csv')
FAN_table_KID9.to_csv('/Users/user/Research/output_csvs/FAN_table_KID9.csv')
CPU_table_KID9.to_pickle('/Users/user/Research/output_csvs/CPU_table_KID9.pickle')
FAN_table_KID9.to_pickle('/Users/user/Research/output_csvs/FAN_table_KID9.pickle')
# Out:
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:24: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:29: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ...

# %%
_KID11=get_tables("KID11")
CPU_table_KID11=_KID11[0]
FAN_table_KID11=_KID11[1]
new_dfs['CPU_mean_KID11']=np.array(CPU_table_KID11.mean())
new_dfs['FAN_mean_KID11']=np.array(FAN_table_KID11.mean())
CPU_table_KID11.to_csv('/Users/user/Research/output_csvs/CPU_table_KID11.csv')
FAN_table_KID11.to_csv('/Users/user/Research/output_csvs/FAN_table_KID11.csv')
CPU_table_KID11.to_pickle('/Users/user/Research/output_csvs/CPU_table_KID11.pickle')
FAN_table_KID11.to_pickle('/Users/user/Research/output_csvs/FAN_table_KID11.pickle')
# Out:
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:24: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /Users/user/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:29: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ...

# %%
new_dfs.to_csv('/Users/user/Research/output_csvs/new_dfs.csv')
new_dfs.to_pickle('/Users/user/Research/output_csvs/new_dfs.pickle')

# %% [markdown]
# # Neural Network prediciton

# %%
sess = tf.InteractiveSession() # Prepare the sesstion

# %%
nInput = 6
nOutput = 3

def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.1)
    return tf.Variable(initial)
def bias_variable(shape):
    initial = tf.constant(0.1,shape=shape)
    return tf.Variable(initial)

# %%
x = tf.placeholder(tf.float32, shape=[None, nInput], name = "input")
#x = tf.placeholder(tf.float32, shape=[nInput], name = "input")
y_ = tf.placeholder(tf.float32, shape=[None, nOutput], name = "output") 
#y_ = tf.placeholder(tf.float32, shape=[nOutput], name = "output") 

w = tf.Variable(tf.zeros([nInput, nOutput]))  #weight
b = tf.Variable(tf.zeros([nOutput])) #bias
x

# %%
#INPUT
CORES=new_dfs.iloc[:,0:6]

INP_cores=[]

for i in range(320):
    tmp=np.array(CORES.iloc[i])
    INP_cores.append(tmp)
    
input_data=np.array(INP_cores)
input_data[0]

new_dfs

# %%
#OUTPUT
EX_tempera=new_dfs.iloc[:,9:12]
#output_data=np.zeros[(320,3)]
OUP_temp=[]

for i in range(320):
        tmp=np.array(EX_tempera.iloc[i])
        OUP_temp.append(tmp)
        
output_data=np.array(OUP_temp)
output_data

# %%
#非線形回帰モデル
# 30分類器 full=connection

#第１層
W_fc1 = weight_variable([nInput,30])
b_fc1 = bias_variable([30])
h_fc1 = tf.nn.relu(tf.matmul(x,W_fc1) + b_fc1) #発火の定義，発火関数はrelu

#第２層
W_fc2 = weight_variable([30,10])
b_fc2 = bias_variable([10])
h_fc2 = tf.nn.relu(tf.matmul(h_fc1,W_fc2) + b_fc2)

keep_prob = tf.placeholder(tf.float32)  #Need to check !! Sotaさんに聞いてみる！

#最終層（OutPut）
W_fc3 = weight_variable([10,3])
b_fc3 = bias_variable([3])
y = tf.nn.relu(tf.matmul(h_fc2,W_fc3) + b_fc3)

#ソフトマックス関数(分類)は省いている
#y = tf.nn.sigmoid(tf.matmul(x,w) + b)

# %%
#y_ = training data , y = predection data 
cross_entropy = tf.reduce_mean(tf.reduce_sum(tf.square(y - y_)))
#train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cross_entropy)
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

# %%
# Training Algorithm and Loss Function
#loss = tf.reduce_mean(tf.reduce_sum(tf.square(y_-y)))
#train_step = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
# Initializing Session
#sess = tf.InteractiveSession()
#sess.run(tf.initialize_all_variables())

# %%
batch_size = 20 # バッチサイズ  
num_data = 320
print(num_data)
for i in range(20000):
    sff_idx = np.random.permutation(num_data)  # num_data をランダムに変化させている（実際には指す順番を変化させている）
    for idx in range(0, num_data, batch_size):
        Input_batch = input_data[sff_idx[idx: idx + batch_size if idx + batch_size < num_data else num_data]]
        Output_batch = output_data[sff_idx[idx: idx + batch_size if idx + batch_size < num_data else num_data]]
     #   train_step.run(feed_dict={x:Input_batch, y_:Output_batch})
        train_step.run(feed_dict={x:Input_batch, y_:Output_batch, keep_prob:1.0})
    if i%1000 == 0:
      #  loss = sess.run(cross_entropy,feed_dict={x:Input, y_:Output})
        loss = sess.run(cross_entropy,feed_dict={x:input_data, y_:output_data, keep_prob:1.0})
        print("set %d"%(i))
        print("loss ={} ".format(loss))
print('end')

# %%
#予測値(y)の算出
NN_predict=sess.run(y, feed_dict={x:input_data, y_: output_data})

# %%
A=[]
B=[]
Teacher_data=[]
for i in range(1,321):
    A.append(i)

for i in range(0,320):
    B.append(NN_predict[i][0])
    Teacher_data.append(output_data[i][0])
    
plt.plot(A, B, "o", label="NN_predict")
plt.plot(A, Teacher_data, "o", label="Measured_data")
plt.xlabel("case") 
plt.ylabel("temperature")
plt.title('NN_exit_air_temperatture prediction(sensor1)')
plt.xlim(-10, 350)
plt.ylim(33, 37.5)
plt.legend(loc ="upper right")
plt.show()

RMS_NN=np.mean((np.array(B)-np.array(Teacher_data))**2)
print("RMS_NN:", RMS_NN)

# %% [markdown]
# # Linear Regression

# %%
from sklearn import linear_model
clf = linear_model.LinearRegression()
INP_cores

# %%
new_dfs.head()

# %%
X_temp= new_dfs.drop("CRAC_set", axis=1)
X_temp= X_temp.drop("CRAC_out", axis=1)
X_temp= X_temp.drop("time", axis=1)
Y_temp=X_temp.drop ("temp1", axis=1)
Y_temp=Y_temp.drop("temp2", axis=1)
Y_temp=Y_temp.drop("temp3", axis=1)
#X_temp=X_temp.as_matrix()
Y_temp.head()

# %%
# 説明変数に CPU_cores を利用
X = Y_temp.as_matrix()
#X=INP_cores
        
# 目的変数に 排出温度を利用
#Y = wine['alcohol'].as_matrix()
Y= X_temp["temp3"].as_matrix()
        
# 予測モデルを作成
clf.fit(X, Y)
 
# 回帰係数
print(clf.coef_)

# 決定係数
print(clf.score(X, Y))

# 偏回帰係数
print(pd.DataFrame({"Name":Y_temp.columns,
                   "Coefficients":clf.coef_}).sort_values(by='Coefficients') )
 
# 切片 (誤差)
print(clf.intercept_)

# %%
Predicted_temperature=[]

for i in range(len(X)):
    g=clf.predict(X[i])
    Predicted_temperature.append(g)

# %%
cases=[]
for i in range(len(Y)):
    cases.append(i)
    
plt.scatter(cases, Predicted_temperature, label="Predicted temperature")
plt.scatter(cases, Y, c="yellow", label="Measured temperature")
plt.xlabel("cases") 
plt.ylabel("temperature")
plt.title('Temperature1 Linear Regression prediction')

plt.legend()
plt.show()

# %%
Error=[]
Error_abs=[]
for i in range(len(Y)):    
    e=Predicted_temperature[i]-Y[i]
    Error.append(e)
    f=abs(e)
    Error_abs.append(f)

#Errorの平均値   
RMS_LR=np.mean((Predicted_temperature - Y) ** 2)
print("2乗誤差の平均値:", RMS_LR)

# %%
plt.scatter(cases, Error, c="red")
plt.xlabel("cases") 
plt.ylabel("Temperature()")
plt.title('RMS_LR(temperature1)')
plt.legend()
plt.show()
